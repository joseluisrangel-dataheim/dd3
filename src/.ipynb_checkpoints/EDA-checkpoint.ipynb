# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Data

# %%
df = pd.read_csv('../data/processed/denue_geo_data.csv')

# %%
len(df)
# Out:
# 2119

# %%
df = df.drop_duplicates(subset=['main_name', 'lat', 'lon'])

# %%
len(df)
# Out:
# 1912

# %% [markdown]
# # Calcular precio por m2

# %%
df.reset_index(drop=True, inplace=True)

# %%
df = df.copy()

# %%
df.isna().sum()
# Out:
# main_name             0
# location            635
# id                    0
# property_type         0
# price_type            0
# days_on_site        848
# lat                   0
# lon                   0
# Baños                18
# Estacionamientos    873
# Recámaras            22
# m2_totales          268
# m2_construidos      637
# years               637
# price_final           0
# source                0
# geometry              0
# index_right           0
# CVEGEO                0
# CVE_ENT               0
# CVE_MUN               0
# CVE_LOC               0
# CVE_AGEB              0
# Ambito                0
# new_id                0
# num_comercios       126
# is_consultorio      126
# is_recreativo       126
# is_retail           126
# is_escuela          126
# dtype: int64

# %%
#Rellenar vacíos con su contraparte de m2
df.loc[df.m2_totales.isna(), 'm2_totales'] = df.m2_construidos
df.loc[df.m2_construidos.isna(), 'm2_construidos'] = df.m2_totales

# %%
df[df.id==1044]
# Out:
#                                      main_name  \
# 1589  Fabuloso Edificio En Renta En Roma Norte
# 1749          11894 av. parque españa, condesa
#
#                                       location    id property_type price_type  \
# 1589  Roma Norte, Cuauhtémoc, Distrito Federal  1044          casa      renta
# 1749                                       NaN  1044          casa      venta
#
#       days_on_site        lat        lon  Baños  Estacionamientos  Recámaras  \
# 1589           5.0  19.435634 -99.149511    NaN               NaN        NaN
# 1749           NaN  19.414520 -99.172180    3.0               NaN        3.0
#
#       m2_totales  m2_construidos  years  price_final          source  \
# 1589       594.0          1146.0    0.0     399031.0  metros_cubicos
# 1749       154.0           154.0    NaN    7500000.0   viva_anuncios
#
#                                    geometry  index_right         CVEGEO  \
# 1589  POINT (-99.14951069999999 19.4356338)        12639  0901500010729
# 1749             POINT (-99.17218 19.41452)        12607  0901500011182
#
#       CVE_ENT  CVE_MUN  CVE_LOC CVE_AGEB  Ambito  new_id  num_comercios  \
# 1589        9       15        1     0729  Urbana    1790          372.0
# 1749        9       15        1     1182  Urbana    1956          147.0
#
#       is_consultorio  is_recreativo  is_retail  is_escuela
# 1589             7.0           55.0       56.0         4.0
# 1749             7.0           32.0       27.0         6.0

# %%
df.isna().sum()
# Out:
# main_name             0
# location            635
# id                    0
# property_type         0
# price_type            0
# days_on_site        848
# lat                   0
# lon                   0
# Baños                18
# Estacionamientos    873
# Recámaras            22
# m2_totales          268
# m2_construidos      268
# years               637
# price_final           0
# source                0
# geometry              0
# index_right           0
# CVEGEO                0
# CVE_ENT               0
# CVE_MUN               0
# CVE_LOC               0
# CVE_AGEB              0
# Ambito                0
# new_id                0
# num_comercios       126
# is_consultorio      126
# is_recreativo       126
# is_retail           126
# is_escuela          126
# dtype: int64

# %%
df.source.value_counts()
# Out:
# metros_cubicos    1277
# viva_anuncios      635
# Name: source, dtype: int64

# %%
df[df.source=='metros_cubicos'][['m2_totales', 'Recámaras', 'Baños']].corr()
# Out:
#             m2_totales  Recámaras     Baños
# m2_totales    1.000000  -0.004238 -0.013904
# Recámaras    -0.004238   1.000000  0.236433
# Baños        -0.013904   0.236433  1.000000

# %%
df[df.source=='viva_anuncios'][['m2_totales', 'Recámaras', 'Baños']].corr()
# Out:
#             m2_totales  Recámaras     Baños
# m2_totales    1.000000   0.612691  0.582359
# Recámaras     0.612691   1.000000  0.617848
# Baños         0.582359   0.617848  1.000000

# %%
df.groupby('source').agg({'m2_totales':'describe'})
# Out:
#                m2_totales                                                     \
#                     count        mean          std   min   25%    50%    75%
# source
# metros_cubicos     1275.0  167.602737  1935.113383   0.0  65.0   90.0  132.5
# viva_anuncios       369.0  112.086721    52.288373  29.0  79.0  103.0  131.0
#
#
#                     max
# source
# metros_cubicos  69002.0
# viva_anuncios     425.0

# %%
sns.boxplot(x='m2_totales', data=df)
# Out:
# <AxesSubplot:xlabel='m2_totales'>

# %%
df[df.m2_totales>1200]
# Out:
#                                               main_name  \
# 210   Venta De Departamentos En Roma Norte Cuauhtemo...
# 1266  Hermoso Departamento De Una Recámara Con Terra...
#
#                                                location   id property_type  \
# 210            Roma Norte, Cuauhtémoc, Distrito Federal  186         depto
# 1266  Real De Romita 4, La Romita, Roma Norte, Ciuda...   69         depto
#
#      price_type  days_on_site        lat        lon  Baños  Estacionamientos  \
# 210       venta           4.0  19.419526 -99.162549    1.0               NaN
# 1266      venta          26.0  19.423639 -99.154122    1.0               NaN
#
#       Recámaras  m2_totales  m2_construidos  years  price_final  \
# 210         1.0      4445.0          4445.0    1.0    3585951.0
# 1266        1.0     69002.0         93000.0    0.0    4995000.0
#
#               source                               geometry  index_right  \
# 210   metros_cubicos          POINT (-99.162549 19.4195256)        12699
# 1266  metros_cubicos  POINT (-99.15412240000001 19.4236389)        12691
#
#              CVEGEO  CVE_ENT  CVE_MUN  CVE_LOC CVE_AGEB  Ambito  new_id  \
# 210   0901500011002        9       15        1     1002  Urbana     227
# 1266  0901500011017        9       15        1     1017  Urbana    1420
#
#       num_comercios  is_consultorio  is_recreativo  is_retail  is_escuela
# 210           317.0            17.0           59.0       71.0        15.0
# 1266          356.0            20.0           54.0      123.0         8.0

# %%
# Corregir datos de m2
df.loc[df.m2_totales>=1200, 'm2_totales'] = np.nan
df.loc[df.m2_construidos>=1200, 'm2_construidos'] = np.nan

# %%
sns.boxplot(x='m2_totales', data=df)
# Out:
# <AxesSubplot:xlabel='m2_totales'>

# %%
df.loc[df.m2_totales<30, 'm2_totales'] = np.nan
df.loc[df.m2_construidos<30, 'm2_construidos'] = np.nan

# %%
#Número de recámaras mayores a 10
df.loc[df['Recámaras']>=10, 'Recámaras'] = np.nan

# %%
df.loc[df['Baños']<0, 'Baños'] = np.nan

# %%
df.head(2)
# Out:
#                                         main_name  \
# 0                Renta Departamento En Roma Norte
# 1  Renta Casa A Estrenar En Condominio Roma Norte
#
#                                             location  id property_type  \
# 0  Av Chapultepec 322, Roma Norte, Ciudad De Méxi...   1         depto
# 1  Cozumel S/n, Roma Norte, Cuauhtémoc, Distrito ...   6          casa
#
#   price_type  days_on_site        lat        lon  Baños  Estacionamientos  \
# 0      renta           6.0  19.422992 -99.164232    2.0               1.0
# 1      renta           4.0  19.419022 -99.170931    4.0               NaN
#
#    Recámaras  m2_totales  m2_construidos  years  price_final          source  \
# 0        2.0        85.0            85.0    1.0      17500.0  metros_cubicos
# 1        3.0       800.0           169.0    0.0      45000.0  metros_cubicos
#
#                          geometry  index_right         CVEGEO  CVE_ENT  \
# 0  POINT (-99.1642322 19.4229918)        12624  0901500010998        9
# 1   POINT (-99.1709307 19.419022)        12624  0901500010998        9
#
#    CVE_MUN  CVE_LOC CVE_AGEB  Ambito  new_id  num_comercios  is_consultorio  \
# 0       15        1     0998  Urbana       1          605.0            17.0
# 1       15        1     0998  Urbana       2          442.0            72.0
#
#    is_recreativo  is_retail  is_escuela  is_depto
# 0          106.0      256.0        12.0         1
# 1           67.0      103.0        13.0         0

# %%
df[['m2_totales', 'Recámaras', 'Baños', 'is_retail']].corr()
# Out:
#             m2_totales  Recámaras     Baños  is_retail
# m2_totales    1.000000   0.548764  0.485417  -0.091143
# Recámaras     0.548764   1.000000  0.629312  -0.043094
# Baños         0.485417   0.629312  1.000000  -0.014238
# is_retail    -0.091143  -0.043094 -0.014238   1.000000

# %%
# Imputar variables de interés con base en kmeans
from sklearn.impute import KNNImputer

# %%
df['is_depto'] = np.where(df['property_type']=='depto', 1, 0)

# %%
df.isna().sum()
# Out:
# main_name             0
# location            635
# id                    0
# property_type         0
# price_type            0
# days_on_site        848
# lat                   0
# lon                   0
# Baños                19
# Estacionamientos    873
# Recámaras            27
# m2_totales          353
# m2_construidos      278
# years               637
# price_final           0
# source                0
# geometry              0
# index_right           0
# CVEGEO                0
# CVE_ENT               0
# CVE_MUN               0
# CVE_LOC               0
# CVE_AGEB              0
# Ambito                0
# new_id                0
# num_comercios       126
# is_consultorio      126
# is_recreativo       126
# is_retail           126
# is_escuela          126
# is_depto              0
# dtype: int64

# %%
X = df[['Baños', 'Recámaras', 'm2_totales', 'm2_construidos', 'is_depto'
       ]]

# %%
imputer = KNNImputer(n_neighbors=5, weights="uniform")
X_imp = imputer.fit_transform(X)

# %%
X_imp_df = pd.DataFrame(X_imp, columns=['Baños_imp', 'Recámaras_imp', 
                                        'm2_totales_imp', 'm2_construidos_imp', 
                                        'is_depto'])

# %%
X_imp_df = X_imp_df.drop(columns=['is_depto'])

# %%
df_imp = df.merge(X_imp_df, how='left', left_index=True, right_index=True)

# %%
df_imp.isna().sum()
# Out:
# main_name               0
# location              635
# id                      0
# property_type           0
# price_type              0
# days_on_site          848
# lat                     0
# lon                     0
# Baños                  19
# Estacionamientos      873
# Recámaras              27
# m2_totales            353
# m2_construidos        278
# years                 637
# price_final             0
# source                  0
# geometry                0
# index_right             0
# CVEGEO                  0
# CVE_ENT                 0
# CVE_MUN                 0
# CVE_LOC                 0
# CVE_AGEB                0
# Ambito                  0
# new_id                  0
# num_comercios         126
# is_consultorio        126
# is_recreativo         126
# is_retail             126
# is_escuela            126
# is_depto                0
# Baños_imp               0
# Recámaras_imp           0
# m2_totales_imp          0
# m2_construidos_imp      0
# dtype: int64

# %%
df_imp[['Baños_imp', 'Recámaras_imp','m2_totales_imp', 'm2_construidos_imp', 
                                        ]].describe()
# Out:
#          Baños_imp  Recámaras_imp  m2_totales_imp  m2_construidos_imp
# count  1912.000000    1912.000000     1912.000000         1912.000000
# mean      1.879184       2.156381      116.418842          116.272871
# std       0.733632       0.856973       77.769516           82.632557
# min       1.000000       1.000000       30.000000           30.000000
# 25%       1.000000       2.000000       74.000000           74.000000
# 50%       2.000000       2.000000       97.000000          100.000000
# 75%       2.000000       3.000000      138.000000          130.000000
# max       8.000000       8.000000     1053.000000         1146.000000

# %%
df_imp.head(1)
# Out:
#                           main_name  \
# 0  Renta Departamento En Roma Norte
#
#                                             location  id property_type  \
# 0  Av Chapultepec 322, Roma Norte, Ciudad De Méxi...   1         depto
#
#   price_type  days_on_site        lat        lon  Baños  Estacionamientos  \
# 0      renta           6.0  19.422992 -99.164232    2.0               1.0
#
#    Recámaras  m2_totales  m2_construidos  years  price_final          source  \
# 0        2.0        85.0            85.0    1.0      17500.0  metros_cubicos
#
#                          geometry  index_right         CVEGEO  CVE_ENT  \
# 0  POINT (-99.1642322 19.4229918)        12624  0901500010998        9
#
#    CVE_MUN  CVE_LOC CVE_AGEB  Ambito  new_id  num_comercios  is_consultorio  \
# 0       15        1     0998  Urbana       1          605.0            17.0
#
#    is_recreativo  is_retail  is_escuela  is_depto  Baños_imp  Recámaras_imp  \
# 0          106.0      256.0        12.0         1        2.0            2.0
#
#    m2_totales_imp  m2_construidos_imp
# 0            85.0                85.0

# %%
#Precio por m2
df_imp['precio_m2'] = np.nan
df_imp.loc[df_imp.price_type=='renta',
            'precio_m2'] = (df_imp.price_final/df_imp.m2_totales_imp) * 12 / .07
df_imp.loc[df_imp.price_type=='venta',
            'precio_m2'] = (df_imp.price_final/df_imp.m2_totales_imp)

# %%
df_imp.precio_m2.describe()
# Out:
# count    1.912000e+03
# mean     7.415659e+04
# std      4.258555e+05
# min      3.461538e+02
# 25%      4.408669e+04
# 50%      5.777778e+04
# 75%      6.907179e+04
# max      1.113067e+07
# Name: precio_m2, dtype: float64

# %%
#Precio por m2 construido
df_imp['precio_m2_con'] = np.nan
df_imp.loc[df_imp.price_type=='renta',
            'precio_m2_con'] = (df_imp.price_final/df_imp.m2_construidos_imp) * 12 / .07
df_imp.loc[df_imp.price_type=='venta',
            'precio_m2_con'] = (df_imp.price_final/df_imp.m2_construidos_imp)

# %%
df_imp['precio_m2_con'].describe()
# Out:
# count    1.912000e+03
# mean     7.312214e+04
# std      4.257128e+05
# min      3.461538e+02
# 25%      4.419275e+04
# 50%      5.713372e+04
# 75%      6.785714e+04
# max      1.113067e+07
# Name: precio_m2_con, dtype: float64

# %% [markdown]
# # Limpieza

# %%
# Los outliers son renta que realmente son venta
df_imp[df_imp.precio_m2>150000].sort_values('precio_m2')
# Out:
#                                               main_name  \
# 573                           Casa En Venta  Roma Norte
# 1133   espectacular pentgarden en pre-venta, roma norte
# 540   hermoso departamento en venta en el corazón de...
# 1130  magnifico departamento con roof garden privado...
# 548           penthouse en colonia roma de 2 recamaras.
# 1091      departamento calle chihuahua, col. roma norte
# 1120                              ph en venta col. roma
# 1105               venta de ph en roma norte cuauhtémoc
# 179                    Casa En Venta Colonia Roma Norte
# 1302        Increíble Casa En Venta Con Local Comercial
# 1119                departamento en venta en roma norte
# 222      Venta Casa En Plaza Rio De Janeiro, Roma Norte
# 246   Hermosa Casa Tipo Neocolonial Mexicano En Vent...
# 1482  departamento en edificio basurto colonia hipod...
# 19    Casa Uso De Suelo  En  Venta En Colonia Roma N...
# 1877                              departamento en venta
# 1757                     d1385 - río ródano, cuauhtémoc
# 1755  departamento venta, col. cuauhtémoc. lujo y es...
# 255   Departamento En Venta En Roma Norte Ff  21 - 2...
# 349         Renta Depta Plaza Río De Janeiro Col. Roma.
# 479           Venta Departamento Roma Norte Apa_2625 Ah
# 484             Departamento En Venta Jalapa Roma Norte
# 463      Super Oportunidad,venta De Depto Col. Roma Nte
#
#                                                location    id property_type  \
# 573   Monterrey 00, Roma Norte, Cuauhtémoc, Distrito...   280          casa
# 1133                                                NaN   816         depto
# 540                                                 NaN   644         depto
# 1130                                                NaN   715         depto
# 548                                                 NaN   737         depto
# 1091                                                NaN   170         depto
# 1120                                                NaN   627         depto
# 1105                                                NaN   405         depto
# 179            Roma Norte, Cuauhtémoc, Distrito Federal     2          casa
# 1302  Cordoba, Roma Norte, Cuauhtémoc, Distrito Federal   531          casa
# 1119                                                NaN   603         depto
# 222   Plaza Rio De Janeiro, Roma Norte, Cuauhtémoc, ...   282          casa
# 246   Plaza Río De Janeiro, Roma Norte, Cuauhtémoc, ...   464          casa
# 1482                                                NaN   851         depto
# 19     Puebla, Roma Norte, Cuauhtémoc, Distrito Federal   313          casa
# 1877                                                NaN  1018         depto
# 1757                                                NaN  1032          casa
# 1755                                                NaN   978         depto
# 255            Roma Norte, Cuauhtémoc, Distrito Federal   698         depto
# 349   Rio De Janeiro, Roma Norte, Cuauhtémoc, Distri...  1143         depto
# 479   Roma Norte 0, Roma Norte, Cuauhtémoc, Distrito...  1753         depto
# 484   Jalapa 000, Roma Norte, Cuauhtémoc, Distrito F...  1783         depto
# 463   Rio De Janeiro 53, Roma Norte, Cuauhtémoc, Dis...  1686         depto
#
#      price_type  days_on_site        lat        lon  Baños  Estacionamientos  \
# 573       venta           4.0  19.414149 -99.164540    8.0               4.0
# 1133      venta           NaN  19.416820 -99.159640    2.0               NaN
# 540       venta           NaN  19.418840 -99.161330    2.0               NaN
# 1130      venta           NaN  19.417110 -99.161210    2.0               NaN
# 548       venta           NaN  19.419520 -99.162540    2.0               NaN
# 1091      venta           NaN  19.417510 -99.159590    2.0               NaN
# 1120      venta           NaN  19.415380 -99.161970    2.0               NaN
# 1105      venta           NaN  19.415380 -99.161970    2.0               NaN
# 179       venta           5.0  19.420580 -99.159129    3.0               1.0
# 1302      venta          11.0  19.421013 -99.158988    3.0               1.0
# 1119      venta           NaN  19.415550 -99.161590    3.0               NaN
# 222       venta           4.0  19.420695 -99.159760    7.0               1.0
# 246       venta          21.0  19.420627 -99.159894    7.0               1.0
# 1482      venta           NaN  19.413580 -99.167750    2.0               NaN
# 19        venta           4.0  19.422116 -99.165054    NaN               NaN
# 1877      venta           NaN  19.411340 -99.170210    2.0               NaN
# 1757      venta           NaN  19.424040 -99.175750    1.0               NaN
# 1755      venta           NaN  19.423990 -99.175880    1.0               NaN
# 255       venta           4.0  19.419526 -99.162549    3.0               2.0
# 349       renta          15.0  19.421390 -99.160494    2.0               1.0
# 479       renta           3.0  19.419526 -99.162549    2.0               2.0
# 484       renta          11.0  19.419526 -99.162549    2.0               1.0
# 463       renta           9.0  19.421073 -99.161050    2.0               1.0
#
#       Recámaras  m2_totales  m2_construidos  years  price_final  \
# 573         8.0       213.0           565.0   70.0   32000000.0
# 1133        2.0         NaN             NaN    NaN   12000000.0
# 540         2.0         NaN             NaN    NaN   12900000.0
# 1130        2.0         NaN             NaN    NaN   13000000.0
# 548         2.0         NaN             NaN    NaN   13000000.0
# 1091        2.0         NaN             NaN    NaN   13000000.0
# 1120        2.0         NaN             NaN    NaN   13170500.0
# 1105        2.0         NaN             NaN    NaN   13170500.0
# 179         3.0       114.0           255.0    0.0   19500000.0
# 1302        3.0       113.0           255.0   11.0   19500000.0
# 1119        3.0        90.0            90.0    NaN   15900000.0
# 222         8.0       209.0           481.0    0.0   38000000.0
# 246         8.0       209.0           491.0    0.0   38000000.0
# 1482        2.0         NaN             NaN    NaN   14800000.0
# 19          NaN       150.0           425.0   26.0   30000000.0
# 1877        2.0         NaN             NaN    NaN   18350000.0
# 1757        1.0        66.0            66.0    NaN   19270060.0
# 1755        1.0         NaN             NaN    NaN   20000000.0
# 255         3.0       284.0           284.0    1.0  147000018.0
# 349         3.0       211.0           211.0    0.0     800000.0
# 479         2.0        97.0            97.0   20.0    6000000.0
# 484         2.0        80.0            80.0    0.0    4950000.0
# 463         2.0       211.0           211.0    0.0   13700000.0
#
#               source                               geometry  index_right  \
# 573   metros_cubicos          POINT (-99.1645398 19.414149)        12610
# 1133   viva_anuncios             POINT (-99.15964 19.41682)        12698
# 540    viva_anuncios    POINT (-99.16133000000001 19.41884)        12699
# 1130   viva_anuncios             POINT (-99.16121 19.41711)        12698
# 548    viva_anuncios    POINT (-99.16254000000001 19.41952)        12699
# 1091   viva_anuncios    POINT (-99.15958999999999 19.41751)        12698
# 1120   viva_anuncios             POINT (-99.16197 19.41538)        12698
# 1105   viva_anuncios             POINT (-99.16197 19.41538)        12698
# 179   metros_cubicos         POINT (-99.1591294 19.4205803)        12699
# 1302  metros_cubicos         POINT (-99.1589883 19.4210127)        12691
# 1119   viva_anuncios             POINT (-99.16159 19.41555)        12698
# 222   metros_cubicos         POINT (-99.1597601 19.4206946)        12699
# 246   metros_cubicos  POINT (-99.15989399999999 19.4206266)        12699
# 1482   viva_anuncios             POINT (-99.16775 19.41358)        12609
# 19    metros_cubicos  POINT (-99.16505410000001 19.4221155)        12624
# 1877   viva_anuncios             POINT (-99.17021 19.41134)        12608
# 1757   viva_anuncios    POINT (-99.17574999999999 19.42404)        12580
# 1755   viva_anuncios    POINT (-99.17588000000001 19.42399)        12580
# 255   metros_cubicos          POINT (-99.162549 19.4195256)        12699
# 349   metros_cubicos         POINT (-99.1604944 19.4213897)        12699
# 479   metros_cubicos          POINT (-99.162549 19.4195256)        12699
# 484   metros_cubicos          POINT (-99.162549 19.4195256)        12699
# 463   metros_cubicos         POINT (-99.1610498 19.4210735)        12699
#
#              CVEGEO  CVE_ENT  CVE_MUN  CVE_LOC CVE_AGEB  Ambito  new_id  \
# 573   0901500011214        9       15        1     1214  Urbana     654
# 1133  0901500011106        9       15        1     1106  Urbana    1257
# 540   0901500011002        9       15        1     1002  Urbana     621
# 1130  0901500011106        9       15        1     1106  Urbana    1254
# 548   0901500011002        9       15        1     1002  Urbana     629
# 1091  0901500011106        9       15        1     1106  Urbana    1215
# 1120  0901500011106        9       15        1     1106  Urbana    1244
# 1105  0901500011106        9       15        1     1106  Urbana    1229
# 179   0901500011002        9       15        1     1002  Urbana     194
# 1302  0901500011017        9       15        1     1017  Urbana    1456
# 1119  0901500011106        9       15        1     1106  Urbana    1243
# 222   0901500011002        9       15        1     1002  Urbana     239
# 246   0901500011002        9       15        1     1002  Urbana     266
# 1482  090150001120A        9       15        1     120A  Urbana    1679
# 19    0901500010998        9       15        1     0998  Urbana      26
# 1877  0901500011197        9       15        1     1197  Urbana    2085
# 1757  0901500010930        9       15        1     0930  Urbana    1964
# 1755  0901500010930        9       15        1     0930  Urbana    1962
# 255   0901500011002        9       15        1     1002  Urbana     275
# 349   0901500011002        9       15        1     1002  Urbana     377
# 479   0901500011002        9       15        1     1002  Urbana     542
# 484   0901500011002        9       15        1     1002  Urbana     547
# 463   0901500011002        9       15        1     1002  Urbana     526
#
#       num_comercios  is_consultorio  is_recreativo  is_retail  is_escuela  \
# 573           421.0            25.0          102.0      100.0         6.0
# 1133          329.0            43.0           84.0       62.0        18.0
# 540           286.0            11.0           61.0       70.0        18.0
# 1130          322.0            24.0           67.0       74.0        16.0
# 548           314.0            17.0           58.0       71.0        15.0
# 1091          329.0            42.0           75.0       62.0        22.0
# 1120          518.0           220.0           75.0       68.0        14.0
# 1105          518.0           220.0           75.0       68.0        14.0
# 179           260.0            17.0           41.0       49.0        18.0
# 1302          302.0            52.0           48.0       51.0        16.0
# 1119          526.0           221.0           76.0       68.0        14.0
# 222           252.0            13.0           42.0       51.0        16.0
# 246           259.0            13.0           40.0       49.0        20.0
# 1482          259.0             6.0           44.0       81.0         8.0
# 19            416.0            21.0           99.0       91.0        11.0
# 1877            NaN             NaN            NaN        NaN         NaN
# 1757          339.0             1.0           58.0       42.0         1.0
# 1755          335.0             1.0           57.0       41.0         1.0
# 255           317.0            17.0           59.0       71.0        15.0
# 349           280.0            16.0           47.0       50.0        14.0
# 479           317.0            17.0           59.0       71.0        15.0
# 484           317.0            17.0           59.0       71.0        15.0
# 463           271.0            15.0           44.0       52.0        15.0
#
#       is_depto  Baños_imp  Recámaras_imp  m2_totales_imp  m2_construidos_imp  \
# 573          0        8.0            8.0         213.000               565.0
# 1133         1        2.0            2.0          77.400               118.8
# 540          1        2.0            2.0          77.400               118.8
# 1130         1        2.0            2.0          77.400               118.8
# 548          1        2.0            2.0          77.400               118.8
# 1091         1        2.0            2.0          77.400               118.8
# 1120         1        2.0            2.0          77.400               118.8
# 1105         1        2.0            2.0          77.400               118.8
# 179          0        3.0            3.0         114.000               255.0
# 1302         0        3.0            3.0         113.000               255.0
# 1119         1        3.0            3.0          90.000                90.0
# 222          0        7.0            8.0         209.000               481.0
# 246          0        7.0            8.0         209.000               491.0
# 1482         1        2.0            2.0          77.400               118.8
# 19           0        2.2            2.2         150.000               425.0
# 1877         1        2.0            2.0          77.400               118.8
# 1757         0        1.0            1.0          66.000                66.0
# 1755         1        1.0            1.0          53.714                57.0
# 255          1        3.0            3.0         284.000               284.0
# 349          1        2.0            3.0         211.000               211.0
# 479          1        2.0            2.0          97.000                97.0
# 484          1        2.0            2.0          80.000                80.0
# 463          1        2.0            2.0         211.000               211.0
#
#          precio_m2  precio_m2_con
# 573   1.502347e+05   5.663717e+04
# 1133  1.550388e+05   1.010101e+05
# 540   1.666667e+05   1.085859e+05
# 1130  1.679587e+05   1.094276e+05
# 548   1.679587e+05   1.094276e+05
# 1091  1.679587e+05   1.094276e+05
# 1120  1.701615e+05   1.108628e+05
# 1105  1.701615e+05   1.108628e+05
# 179   1.710526e+05   7.647059e+04
# 1302  1.725664e+05   7.647059e+04
# 1119  1.766667e+05   1.766667e+05
# 222   1.818182e+05   7.900208e+04
# 246   1.818182e+05   7.739308e+04
# 1482  1.912145e+05   1.245791e+05
# 19    2.000000e+05   7.058824e+04
# 1877  2.370801e+05   1.544613e+05
# 1757  2.919706e+05   2.919706e+05
# 1755  3.723424e+05   3.508772e+05
# 255   5.176057e+05   5.176057e+05
# 349   6.499661e+05   6.499661e+05
# 479   1.060383e+07   1.060383e+07
# 484   1.060714e+07   1.060714e+07
# 463   1.113067e+07   1.113067e+07

# %%
df_imp['main_name'] = df_imp['main_name'].str.lower()

# %%
df_imp.loc[df_imp.main_name.str.contains('venta'), 'price_type'] = 'venta'

# %%
#Precio por m2
df_imp['precio_m2'] = np.nan
df_imp.loc[df_imp.price_type=='renta',
            'precio_m2'] = (df_imp.price_final/df_imp.m2_totales_imp) * 12 / .07
df_imp.loc[df_imp.price_type=='venta',
            'precio_m2'] = (df_imp.price_final/df_imp.m2_totales_imp)

# %%
df_imp.precio_m2.describe()
# Out:
# count      1912.000000
# mean      57340.180669
# std       32032.364111
# min         346.153846
# 25%       44086.691410
# 50%       57777.777778
# 75%       69004.032258
# max      649966.147596
# Name: precio_m2, dtype: float64

# %%
#Precio por m2 construido
df_imp['precio_m2_con'] = np.nan
df_imp.loc[df_imp.price_type=='renta',
            'precio_m2_con'] = (df_imp.price_final/df_imp.m2_construidos_imp) * 12 / .07
df_imp.loc[df_imp.price_type=='venta',
            'precio_m2_con'] = (df_imp.price_final/df_imp.m2_construidos_imp)

# %%
df_imp.sort_values('precio_m2').tail(5)
# Out:
#                                               main_name  \
# 1877                              departamento en venta
# 1757                     d1385 - río ródano, cuauhtémoc
# 1755  departamento venta, col. cuauhtémoc. lujo y es...
# 255   departamento en venta en roma norte ff  21 - 2...
# 349         renta depta plaza río de janeiro col. roma.
#
#                                                location    id property_type  \
# 1877                                                NaN  1018         depto
# 1757                                                NaN  1032          casa
# 1755                                                NaN   978         depto
# 255            Roma Norte, Cuauhtémoc, Distrito Federal   698         depto
# 349   Rio De Janeiro, Roma Norte, Cuauhtémoc, Distri...  1143         depto
#
#      price_type  days_on_site        lat        lon  Baños  Estacionamientos  \
# 1877      venta           NaN  19.411340 -99.170210    2.0               NaN
# 1757      venta           NaN  19.424040 -99.175750    1.0               NaN
# 1755      venta           NaN  19.423990 -99.175880    1.0               NaN
# 255       venta           4.0  19.419526 -99.162549    3.0               2.0
# 349       renta          15.0  19.421390 -99.160494    2.0               1.0
#
#       Recámaras  m2_totales  m2_construidos  years  price_final  \
# 1877        2.0         NaN             NaN    NaN   18350000.0
# 1757        1.0        66.0            66.0    NaN   19270060.0
# 1755        1.0         NaN             NaN    NaN   20000000.0
# 255         3.0       284.0           284.0    1.0  147000018.0
# 349         3.0       211.0           211.0    0.0     800000.0
#
#               source                             geometry  index_right  \
# 1877   viva_anuncios           POINT (-99.17021 19.41134)        12608
# 1757   viva_anuncios  POINT (-99.17574999999999 19.42404)        12580
# 1755   viva_anuncios  POINT (-99.17588000000001 19.42399)        12580
# 255   metros_cubicos        POINT (-99.162549 19.4195256)        12699
# 349   metros_cubicos       POINT (-99.1604944 19.4213897)        12699
#
#              CVEGEO  CVE_ENT  CVE_MUN  CVE_LOC CVE_AGEB  Ambito  new_id  \
# 1877  0901500011197        9       15        1     1197  Urbana    2085
# 1757  0901500010930        9       15        1     0930  Urbana    1964
# 1755  0901500010930        9       15        1     0930  Urbana    1962
# 255   0901500011002        9       15        1     1002  Urbana     275
# 349   0901500011002        9       15        1     1002  Urbana     377
#
#       num_comercios  is_consultorio  is_recreativo  is_retail  is_escuela  \
# 1877            NaN             NaN            NaN        NaN         NaN
# 1757          339.0             1.0           58.0       42.0         1.0
# 1755          335.0             1.0           57.0       41.0         1.0
# 255           317.0            17.0           59.0       71.0        15.0
# 349           280.0            16.0           47.0       50.0        14.0
#
#       is_depto  Baños_imp  Recámaras_imp  m2_totales_imp  m2_construidos_imp  \
# 1877         1        2.0            2.0          77.400               118.8
# 1757         0        1.0            1.0          66.000                66.0
# 1755         1        1.0            1.0          53.714                57.0
# 255          1        3.0            3.0         284.000               284.0
# 349          1        2.0            3.0         211.000               211.0
#
#           precio_m2  precio_m2_con
# 1877  237080.103359  154461.279461
# 1757  291970.606061  291970.606061
# 1755  372342.406077  350877.192982
# 255   517605.697183  517605.697183
# 349   649966.147596  649966.147596

# %%
ax = sns.boxplot(x='precio_m2', data=df_imp)
ax.set_xlim(0, 100000)
plt.show()

# %%
df_imp.groupby('property_type').agg({'precio_m2':'mean',
                        'precio_m2_con':'mean',
                        'id':'count'
                       })
# Out:
#                   precio_m2  precio_m2_con    id
# property_type
# casa           57294.994167   54565.347671   269
# depto          57347.578824   56590.670702  1643

# %%
# Hay que separar entre casas y deptos

# %%
df_imp['m2_ratio'] = df_imp['m2_construidos_imp']/df_imp['m2_totales_imp']

# %%
df_imp['m2_ratio'].describe()
# Out:
# count    1912.000000
# mean        1.026898
# std         0.246265
# min         0.075000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         3.680000
# Name: m2_ratio, dtype: float64

# %%
df_imp['m2_price_ratio'] = df_imp['precio_m2_con']/df_imp['precio_m2']

# %%
df_imp[['m2_ratio', 'm2_price_ratio']].corr()
# Out:
#                 m2_ratio  m2_price_ratio
# m2_ratio        1.000000       -0.558476
# m2_price_ratio -0.558476        1.000000

# %%
sns.scatterplot(x='m2_ratio', y='m2_price_ratio', data=df_imp)
# Out:
# <AxesSubplot:xlabel='m2_ratio', ylabel='m2_price_ratio'>

# %%
df_imp.sort_values('m2_ratio').head(5)
# Out:
#                                               main_name  \
# 1144             departamento renta con muebles condesa
# 561               depa en la roma norte acepto creditos
# 848     departamento en colonia roma norte, oportunidad
# 1        renta casa a estrenar en condominio roma norte
# 2     roma norte venta de hermosa casa con acabados ...
#
#                                                location    id property_type  \
# 1144  Cda, Salamanca 73, Roma Norte, Cuauhtémoc, Dis...   312         depto
# 561   Zacatecas 0, Roma Norte, Cuauhtémoc, Distrito ...    55         depto
# 848                        Cuauhtémoc, Distrito Federal  1567         depto
# 1     Cozumel S/n, Roma Norte, Cuauhtémoc, Distrito ...     6          casa
# 2     Cozumel Sn, Roma Norte, Cuauhtémoc, Distrito F...    52          casa
#
#      price_type  days_on_site        lat        lon  Baños  Estacionamientos  \
# 1144      renta           9.0  19.418607 -99.169656    1.0               1.0
# 561       venta          11.0  19.414149 -99.164540    2.0               1.0
# 848       venta           2.0  19.418054 -99.158525    2.0               NaN
# 1         renta           4.0  19.419022 -99.170931    4.0               NaN
# 2         venta          41.0  19.419080 -99.170915    3.0               NaN
#
#       Recámaras  m2_totales  m2_construidos  years  price_final  \
# 1144        2.0      1000.0            75.0   12.0      18500.0
# 561         3.0      1053.0            93.0   15.0    4500000.0
# 848         3.0       600.0            70.0    0.0     902000.0
# 1           3.0       800.0           169.0    0.0      45000.0
# 2           3.0       800.0           169.0    1.0   11599000.0
#
#               source                        geometry  index_right  \
# 1144  metros_cubicos  POINT (-99.1696563 19.4186073)        12675
# 561   metros_cubicos   POINT (-99.1645398 19.414149)        12610
# 848   metros_cubicos  POINT (-99.1585252 19.4180537)        12692
# 1     metros_cubicos   POINT (-99.1709307 19.419022)        12624
# 2     metros_cubicos  POINT (-99.1709152 19.4190796)        12624
#
#              CVEGEO  CVE_ENT  CVE_MUN  CVE_LOC CVE_AGEB  Ambito  new_id  \
# 1144  0901500011093        9       15        1     1093  Urbana    1269
# 561   0901500011214        9       15        1     1214  Urbana     642
# 848   0901500011110        9       15        1     1110  Urbana     957
# 1     0901500010998        9       15        1     0998  Urbana       2
# 2     0901500010998        9       15        1     0998  Urbana       3
#
#       num_comercios  is_consultorio  is_recreativo  is_retail  is_escuela  \
# 1144          495.0            82.0           73.0      112.0        13.0
# 561           421.0            25.0          102.0      100.0         6.0
# 848           325.0            36.0           71.0       67.0        19.0
# 1             442.0            72.0           67.0      103.0        13.0
# 2             447.0            72.0           69.0      105.0        13.0
#
#       is_depto  Baños_imp  Recámaras_imp  m2_totales_imp  m2_construidos_imp  \
# 1144         1        1.0            2.0          1000.0                75.0
# 561          1        2.0            3.0          1053.0                93.0
# 848          1        2.0            3.0           600.0                70.0
# 1            0        4.0            3.0           800.0               169.0
# 2            0        3.0            3.0           800.0               169.0
#
#          precio_m2  precio_m2_con  m2_ratio  m2_price_ratio
# 1144   3171.428571   42285.714286  0.075000       13.333333
# 561    4273.504274   48387.096774  0.088319       11.322581
# 848    1503.333333   12885.714286  0.116667        8.571429
# 1      9642.857143   45646.661031  0.211250        4.733728
# 2     14498.750000   68633.136095  0.211250        4.733728

# %%
df_imp.loc[(df_imp.m2_price_ratio>2.5)&(df_imp.property_type=='depto'), 
           'm2_totales_imp'] = df_imp.m2_construidos_imp

# %%
df_imp.sort_values('m2_ratio').tail(5)
# Out:
#                                               main_name  \
# 1454                     champoton roma norte cuauh jlp
# 573                           casa en venta  roma norte
# 19    casa uso de suelo  en  venta en colonia roma n...
# 593              hermosa casa en chiapas roma norte js*
# 1728                co venta departamento en la condesa
#
#                                                location    id property_type  \
# 1454  Calle Champotón 15, Roma Sur, Ciudad De México...  1951          casa
# 573   Monterrey 00, Roma Norte, Cuauhtémoc, Distrito...   280          casa
# 19     Puebla, Roma Norte, Cuauhtémoc, Distrito Federal   313          casa
# 593   Chiapas 127, Roma Norte, Cuauhtémoc, Distrito ...   461          casa
# 1728  Colima 415, Roma Norte, Ciudad De México, Cdmx...  1754         depto
#
#      price_type  days_on_site        lat        lon  Baños  Estacionamientos  \
# 1454      venta           2.0  19.408860 -99.166708    2.0               1.0
# 573       venta           4.0  19.414149 -99.164540    8.0               4.0
# 19        venta           4.0  19.422116 -99.165054    NaN               NaN
# 593       venta           3.0  19.412703 -99.161927    2.0               1.0
# 1728      venta          25.0  19.417422 -99.171953    1.0               1.0
#
#       Recámaras  m2_totales  m2_construidos  years  price_final  \
# 1454        4.0       102.0           264.0    0.0    1648623.0
# 573         8.0       213.0           565.0   70.0   32000000.0
# 19          NaN       150.0           425.0   26.0   30000000.0
# 593         3.0        51.0           178.0    0.0    1007000.0
# 1728        3.0        50.0           184.0    0.0     947073.0
#
#               source                               geometry  index_right  \
# 1454  metros_cubicos         POINT (-99.1667083 19.4088603)        12666
# 573   metros_cubicos          POINT (-99.1645398 19.414149)        12610
# 19    metros_cubicos  POINT (-99.16505410000001 19.4221155)        12624
# 593   metros_cubicos         POINT (-99.1619273 19.4127033)        12610
# 1728  metros_cubicos  POINT (-99.17195270000001 19.4174221)        12607
#
#              CVEGEO  CVE_ENT  CVE_MUN  CVE_LOC CVE_AGEB  Ambito  new_id  \
# 1454  0901500011356        9       15        1     1356  Urbana    1651
# 573   0901500011214        9       15        1     1214  Urbana     654
# 19    0901500010998        9       15        1     0998  Urbana      26
# 593   0901500011214        9       15        1     1214  Urbana     677
# 1728  0901500011182        9       15        1     1182  Urbana    1935
#
#       num_comercios  is_consultorio  is_recreativo  is_retail  is_escuela  \
# 1454          692.0           301.0           70.0      117.0         6.0
# 573           421.0            25.0          102.0      100.0         6.0
# 19            416.0            21.0           99.0       91.0        11.0
# 593           461.0           207.0           61.0       70.0         4.0
# 1728          316.0            64.0           37.0       70.0         8.0
#
#       is_depto  Baños_imp  Recámaras_imp  m2_totales_imp  m2_construidos_imp  \
# 1454         0        2.0            4.0           102.0               264.0
# 573          0        8.0            8.0           213.0               565.0
# 19           0        2.2            2.2           150.0               425.0
# 593          0        2.0            3.0            51.0               178.0
# 1728         1        1.0            3.0            50.0               184.0
#
#           precio_m2  precio_m2_con  m2_ratio  m2_price_ratio
# 1454   16162.970588    6244.784091  2.588235        0.386364
# 573   150234.741784   56637.168142  2.652582        0.376991
# 19    200000.000000   70588.235294  2.833333        0.352941
# 593    19745.098039    5657.303371  3.490196        0.286517
# 1728   18941.460000    5147.135870  3.680000        0.271739

# %%
df_imp.groupby('property_type').agg({'precio_m2':['median', 'mean'],
                        'precio_m2_con':['median', 'mean'],
                        'id':'count'
                       })
# Out:
#                   precio_m2               precio_m2_con                  id
#                      median          mean        median          mean count
# property_type
# casa           58577.586207  57294.994167  54597.701149  54565.347671   269
# depto          57734.814815  57347.578824  57407.407407  56590.670702  1643

# %%
#Tomar precio de casa en construcción y depto normal
df_imp.loc[df_imp.property_type=='casa', 'precio_m2_final'] = df_imp.precio_m2_con
df_imp.loc[df_imp.property_type=='depto', 'precio_m2_final'] = df_imp.precio_m2

# %%
df_imp.precio_m2_final.describe()
# Out:
# count      1912.000000
# mean      56956.145675
# std       31076.735248
# min         346.153846
# 25%       44086.691410
# 50%       57484.641026
# 75%       68715.253165
# max      649966.147596
# Name: precio_m2_final, dtype: float64

# %%
lower = df_imp.precio_m2_final.mean()-df_imp.precio_m2_final.std()
upper = df_imp.precio_m2_final.mean()+df_imp.precio_m2_final.std()

# %%
len(df_imp)
# Out:
# 1912

# %%
df_final = df_imp[df_imp.precio_m2_final>lower]
df_final = df_final[df_final.precio_m2_final<upper]

# %%
len(df_final)
# Out:
# 1574

# %%
df_final.head(1)
# Out:
#                           main_name  \
# 0  renta departamento en roma norte
#
#                                             location  id property_type  \
# 0  Av Chapultepec 322, Roma Norte, Ciudad De Méxi...   1         depto
#
#   price_type  days_on_site        lat        lon  Baños  Estacionamientos  \
# 0      renta           6.0  19.422992 -99.164232    2.0               1.0
#
#    Recámaras  m2_totales  m2_construidos  years  price_final          source  \
# 0        2.0        85.0            85.0    1.0      17500.0  metros_cubicos
#
#                          geometry  index_right         CVEGEO  CVE_ENT  \
# 0  POINT (-99.1642322 19.4229918)        12624  0901500010998        9
#
#    CVE_MUN  CVE_LOC CVE_AGEB  Ambito  new_id  num_comercios  is_consultorio  \
# 0       15        1     0998  Urbana       1          605.0            17.0
#
#    is_recreativo  is_retail  is_escuela  is_depto  Baños_imp  Recámaras_imp  \
# 0          106.0      256.0        12.0         1        2.0            2.0
#
#    m2_totales_imp  m2_construidos_imp     precio_m2  precio_m2_con  m2_ratio  \
# 0            85.0                85.0  35294.117647   35294.117647       1.0
#
#    m2_price_ratio  precio_m2_final
# 0             1.0     35294.117647

# %%
df_final.to_csv('../data/processed/final_dataset.csv', index=False)

# %%
sns.histplot(df_final.precio_m2_final)
# Out:
# <AxesSubplot:xlabel='precio_m2_final', ylabel='Count'>

# %%
# Mapa

# %%
import geopandas as gdp
from dateutil import relativedelta
from shapely.geometry import mapping
import gmplot

# %%
agebs_geo = gdp.read_file("../data/raw/agebs/00a.shp")  
agebs_geo = agebs_geo.to_crs(epsg=4326)

# %%
precio_medio_ageb = df_final.groupby('CVEGEO').agg({'precio_m2_final':'mean',
                                                        'id':'count'
                                                         }).reset_index()

# %%
precio_medio_ageb = precio_medio_ageb[precio_medio_ageb.id>5]

# %%
agebs_geo_map = agebs_geo.copy()
agebs_geo_map = agebs_geo_map[['CVEGEO', 'geometry']]
agebs_geo_map = agebs_geo_map.drop_duplicates(subset=['CVEGEO'])

# %%
precio_medio_ageb.head(1)
# Out:
#           CVEGEO  precio_m2_final  id
# 8  0901500010729     59607.050989  85

# %%
agebs_geo_map = agebs_geo_map.merge(precio_medio_ageb, 
                                    how='left', on='CVEGEO')

# %%
agebs_geo_map = agebs_geo_map.dropna(subset=['precio_m2_final'])

# %%
agebs_geo_map = agebs_geo_map.reset_index(drop=True)

# %%
g = [i for i in agebs_geo_map.geometry]

# %%
agebs_geo_map['ponde'] = (
    (agebs_geo_map.precio_m2_final-agebs_geo_map.precio_m2_final.min()) /
    (agebs_geo_map.precio_m2_final.max()-agebs_geo_map.precio_m2_final.min())
)

# %%
len(g)
# Out:
# 23

# %%
gmap = gmplot.GoogleMapPlotter(21.472548998857, -100.71556222583472, 5, apikey="AIzaSyAVEFQTalNkMzr00eHqMfFAbv1aFxLyrVc")
for i in range(0, len(g)):
    all_coords = mapping(g[i])["coordinates"]
    ponde = agebs_geo_map['ponde'][i]
    
    coords = []
    for j in range(0, len(all_coords[0])):
        temp_coord = [all_coords[0][j][1], all_coords[0][j][0]]
        coord_tuple = tuple(temp_coord)
        coords.append(coord_tuple)
        
    agebs = zip(*coords)
    gmap.polygon(*agebs, color='#D21404', edge_width=1, face_alpha=ponde)


gmap.draw('../results/pricemap.html')
